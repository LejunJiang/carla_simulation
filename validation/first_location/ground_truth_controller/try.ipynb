# %%
import pandas as pd
import numpy as np
df = pd.read_pickle('out/results_1.pd')
df
# Out:
#       initial_x   initial_y  initial_theta  initial_cte  initial_theta_e  \
# 0   -137.738651  149.850321     181.209330    -0.019691         0.027893
# 1   -137.738651  150.264547     161.596440    -0.010912        -0.314417
# 2   -137.738651  149.911543     142.401787     0.714885        -0.649431
# 3   -137.738651  150.239489     160.817179     0.024392        -0.327879
# 4   -137.738651  149.131692     195.245214     0.394257         0.272852
# ..          ...         ...            ...          ...              ...
# 251 -137.738651  149.726186     158.903191     0.584997        -0.361419
# 252 -137.738651  149.692525     167.356868     0.441379        -0.213874
# 253 -137.738651  150.766285     182.773137    -0.971635         0.055200
# 254 -137.738651  150.759477     175.594497    -0.804671        -0.070098
# 255 -137.738651  149.253307     188.299795     0.422934         0.151652
#
#      lane_invasion_count  collision_count  complete_a_loop   max_cte  \
# ...

# %%
# according to max_cte
import matplotlib.pyplot as plt

plt.figure()
# for i in range(len(df['initial_cte'])):
#     if df['max_cte'][i] > df['max_cte_baseline'][i] + 0.6:
#         plt.plot(df['initial_cte'][i], df['initial_theta_e'][i], "r.")
#     else:
#         plt.plot(df['initial_cte'][i], df['initial_theta_e'][i], "b.")

plt.scatter(df['initial_cte'], df['initial_theta_e'], c= df['max_cte'] - df['max_cte_baseline'])
plt.colorbar()
plt.xlabel('cte')
plt.ylabel('theta_e')
plt.show()

# %%
# according to mean_cte
import matplotlib.pyplot as plt

plt.figure()
# for i in range(len(df['initial_cte'])):
#     if df['max_cte'][i] > df['max_cte_baseline'][i] + 0.6:
#         plt.plot(df['initial_cte'][i], df['initial_theta_e'][i], "r.")
#     else:
#         plt.plot(df['initial_cte'][i], df['initial_theta_e'][i], "b.")

plt.scatter(df['initial_cte'], df['initial_theta_e'], c= df['mean_cte'] - df['mean_cte_baseline'])
plt.colorbar()
plt.xlabel('cte')
plt.ylabel('theta_e')
plt.show()
